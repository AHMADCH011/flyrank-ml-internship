# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AHMADCH011/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
## My Lane as an ML Task

Task Type: Classification

The goal is to predict whether a documentation page is likely to confuse users based on historical usage data.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 2. Target or Proxy

## Target or Proxy

Target:
Whether a documentation page causes users to leave without finding an answer.

Proxy:
High bounce rate or low user satisfaction score.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 3. Success Metric
## Success Metric

The primary metric is F1-score because both false positives and false negatives are important.

A high F1-score means the model correctly identifies problematic documentation pages while minimizing incorrect predictions.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/starter_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1399/1219083495.py in <cell line: 0>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv("../../data/starter_dataset.csv")
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
import os

found = False

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.endswith((".csv", ".parquet", ".xlsx", ".json")):
            print(os.path.join(root, file))
            found = True

if not found:
    print("No dataset files found.")
# Out:
# /content/.config/.last_update_check.json
# /content/sample_data/anscombe.json
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/mnist_train_small.csv

# %%
# !git clone https://github.com/AHMADCH011/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 140 (delta 49), reused 91 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 1.85 MiB | 5.01 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
import os

for root, dirs, files in os.walk("/content/REPOSITORY"):
    for file in files:
        if file.endswith((".csv", ".parquet", ".xlsx", ".json")):
            print(os.path.join(root, file))

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
